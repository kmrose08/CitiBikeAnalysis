# %%
import pandas as pd

# %%
# df01 = pd.read_csv("April2018Clean.csv")
# df02 = pd.read_csv("May2018Clean.csv")
# df03 = pd.read_csv("June2018Clean.csv")
# df04 = pd.read_csv("July2018Clean.csv")
# df05 = pd.read_csv("Aug2018Clean.csv")
# df06 = pd.read_csv("Sept2018Clean.csv")

# %%
df01 = pd.read_csv("April2018Clean.csv")
df01.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           840  2018-04-01 03:07:39.0700  2018-04-01 03:21:39.1280
# 1          1438  2018-04-01 07:20:02.2150  2018-04-01 07:44:00.5690
# 2           219  2018-04-01 08:11:14.4060  2018-04-01 08:14:53.7880
# 3           410  2018-04-01 08:52:32.3730  2018-04-01 08:59:23.2190
# 4           485  2018-04-01 09:37:34.3270  2018-04-01 09:45:39.9980
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id       end station name  \
# 0               -73.993929             379        W 31 St & 7 Ave
# ...

# %%
df01 = pd.read_csv("April2018Clean.csv")
df02 = pd.read_csv("May2018Clean.csv")
df03 = pd.read_csv("June2018Clean.csv")
df04 = pd.read_csv("July2018Clean.csv")
df05 = pd.read_csv("Aug2018Clean.csv")
df06 = pd.read_csv("Sept2018Clean.csv")

# %%
cmp_df = pd.concat([df01,df02,df03,df04,df05,df06], ignore_index=True)
cmp_df.tail()
# Out:
#           tripduration                 starttime                  stoptime  \
# 10854037           369  2018-09-30 00:27:25.9840  2018-09-30 00:33:35.7070
# 10854038           191  2018-09-30 00:30:30.1850  2018-09-30 00:33:42.1090
# 10854039          1442  2018-09-30 08:10:03.1790  2018-09-30 08:34:05.3870
# 10854040           453  2018-09-30 12:20:13.6830  2018-09-30 12:27:46.9140
# 10854041          1354  2018-09-30 14:10:01.1620  2018-09-30 14:32:36.1280
#
#           start station id         start station name  start station latitude  \
# 10854037            3601.0  Sterling St & Bedford Ave               40.662706
# 10854038            3601.0  Sterling St & Bedford Ave               40.662706
# 10854039            3601.0  Sterling St & Bedford Ave               40.662706
# 10854040            3601.0  Sterling St & Bedford Ave               40.662706
# 10854041            3601.0  Sterling St & Bedford Ave               40.662706
#
# ...

# %%
cmp_df.to_csv('2018Clean.csv')

# %%
df02 = pd.read_csv("May2018Clean.csv")
df02.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           367  2018-05-01 05:06:16.5840  2018-05-01 05:12:23.9650
# 1          1313  2018-05-01 06:25:49.4250  2018-05-01 06:47:42.7120
# 2          1798  2018-05-01 06:40:26.4450  2018-05-01 07:10:25.1790
# 3           518  2018-05-01 07:06:02.9730  2018-05-01 07:14:41.0040
# 4           109  2018-05-01 07:26:32.3450  2018-05-01 07:28:21.5420
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929             514         12 Ave & W 40 St
# ...

# %%
df03 = pd.read_csv("June2018Clean.csv")
df03.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           569  2018-06-01 01:57:20.5140  2018-06-01 02:06:50.0880
# 1           480  2018-06-01 02:02:42.3980  2018-06-01 02:10:43.3540
# 2           692  2018-06-01 02:04:23.6240  2018-06-01 02:15:55.7470
# 3           664  2018-06-01 03:00:55.4610  2018-06-01 03:11:59.9060
# 4           818  2018-06-01 06:04:54.4270  2018-06-01 06:18:32.6170
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id    end station name  \
# 0               -73.993929             173  Broadway & W 49 St
# ...

# %%
df04 = pd.read_csv("July2018Clean.csv")
df04.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           500  2018-07-01 00:33:51.2640  2018-07-01 00:42:12.0280
# 1           455  2018-07-01 02:06:54.0270  2018-07-01 02:14:29.0900
# 2          1080  2018-07-01 02:09:16.4640  2018-07-01 02:27:17.0290
# 3           632  2018-07-01 02:55:04.5870  2018-07-01 03:05:36.7910
# 4          1676  2018-07-01 03:24:27.4350  2018-07-01 03:52:23.7760
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id    end station name  \
# 0               -73.993929            3236  W 42 St & Dyer Ave
# ...

# %%
df05 = pd.read_csv("Aug2018Clean.csv")
df05.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           681  2018-08-01 00:00:07.3210  2018-08-01 00:11:28.9920
# 1           625  2018-08-01 00:00:19.7480  2018-08-01 00:10:45.0290
# 2          1319  2018-08-01 00:00:21.1750  2018-08-01 00:22:20.6370
# 3           220  2018-08-01 00:00:26.4700  2018-08-01 00:04:06.8190
# 4           398  2018-08-01 00:00:30.2910  2018-08-01 00:07:09.2810
#
#    start station id       start station name  start station latitude  \
# 0            3162.0       W 78 St & Broadway               40.783400
# 1            3260.0  Mercer St & Bleecker St               40.727064
# 2             403.0           E 2 St & 2 Ave               40.725029
# 3            3637.0  Fulton St & Waverly Ave               40.683239
# 4            3662.0     31 Ave & Steinway St               40.761294
#
#    start station longitude  end station id             end station name  \
# ...

# %%
df06 = pd.read_csv("Sept2018Clean.csv")
df06.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1635  2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340
# 1           132  2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810
# 2          3337  2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470
# 3           436  2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830
# 4          8457  2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080
#
#    start station id               start station name  start station latitude  \
# 0             252.0     MacDougal St & Washington Sq               40.732264
# 1             314.0  Cadman Plaza West & Montague St               40.693830
# 2            3142.0                  1 Ave & E 62 St               40.761227
# 3             308.0          St James Pl & Oliver St               40.713079
# 4             345.0                  W 13 St & 6 Ave               40.736494
#
#    start station longitude  end station id            end station name  \
# ...

# %%
df01 = pd.read_csv("April2018Clean.csv")
df02 = pd.read_csv("May2018Clean.csv")
df03 = pd.read_csv("June2018Clean.csv")
df04 = pd.read_csv("July2018Clean.csv")
df05 = pd.read_csv("Aug2018Clean.csv")
df06 = pd.read_csv("Sept2018Clean.csv")

# %%
df11 = pd.read_csv("April2019Clean.csv")
df11.head()
# Out:
#    tripduration starttime stoptime  start station id      start station name  \
# 0            88   00:14.7  01:42.9              2006  Central Park S & 6 Ave
# 1           443   00:20.8  07:44.3               254         W 11 St & 6 Ave
# 2           662   00:31.0  11:33.3              3244  University Pl & E 8 St
# 3            86   00:30.9  01:57.0               526         E 33 St & 5 Ave
# 4           136   00:32.6  02:49.4               461         E 20 St & 2 Ave
#
#    start station latitude  start station longitude  end station id  \
# 0               40.765909               -73.976342            2006
# 1               40.735324               -73.998004             540
# 2               40.731437               -73.994903            3244
# 3               40.747659               -73.984907             474
# 4               40.735877               -73.982050             504
#
#           end station name  end station latitude  end station longitude  \
# ...

# %%
df12 = pd.read_csv("May2019Clean.csv")
df12.head()
# Out:
#    tripduration starttime stoptime  start station id  \
# 0           139   00:01.9  02:21.5               447
# 1           754   00:03.0  12:37.7              3258
# 2          2308   00:04.6  38:33.2              3093
# 3           143   00:19.3  02:42.5              3486
# 4           138   00:22.2  02:40.6               388
#
#           start station name  start station latitude  start station longitude  \
# 0            8 Ave & W 52 St               40.763707               -73.985162
# 1           W 27 St & 10 Ave               40.750182               -74.002184
# 2       N 6 St & Bedford Ave               40.717452               -73.958509
# 3  Schermerhorn St & Bond St               40.688417               -73.984517
# 4           W 26 St & 10 Ave               40.749718               -74.002950
#
#    end station id            end station name  end station latitude  \
# 0             423             W 54 St & 9 Ave             40.765849
# ...

# %%
df13 = pd.read_csv("June2019Clean.csv")
df13.head()
# Out:
#    tripduration starttime stoptime  start station id       start station name  \
# 0           330   00:01.5  05:31.8              3602           31 Ave & 34 St
# 1           830   00:04.2  13:55.1              3054  Greene Ave & Throop Ave
# 2           380   00:06.0  06:26.8               229           Great Jones St
# 3          1155   00:06.8  19:22.5              3771  McKibbin St & Bogart St
# 4          1055   00:07.5  17:42.6               441          E 52 St & 2 Ave
#
#    start station latitude  start station longitude  end station id  \
# 0               40.763154               -73.920827            3570
# 1               40.689493               -73.942061            3781
# 2               40.727434               -73.993790             326
# 3               40.706237               -73.933871            3016
# 4               40.756014               -73.967416            3159
#
#         end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
df14 = pd.read_csv("July2019Clean.csv")
df14.head()
# Out:
#    tripduration starttime stoptime  start station id       start station name  \
# 0           897   00:00.1  14:58.0               493          W 45 St & 6 Ave
# 1           267   00:05.2  04:32.4              3143          5 Ave & E 78 St
# 2          2201   00:05.2  36:46.7               317        E 6 St & Avenue B
# 3          1660   00:08.6  27:48.8               249  Harrison St & Hudson St
# 4           109   00:12.2  02:01.6              3552      W 113 St & Broadway
#
#    start station latitude  start station longitude  end station id  \
# 0               40.756800               -73.982912             454
# 1               40.776321               -73.964274            3226
# 2               40.724537               -73.981854            3469
# 3               40.718710               -74.009001             369
# 4               40.805973               -73.964928            3538
#
#               end station name  end station latitude  end station longitude  \
# ...

# %%
df15 = pd.read_csv("Aug2019Clean.csv")
df15.head()
# Out:
#    tripduration starttime stoptime  start station id  \
# 0           393   00:01.5  06:35.4             531.0
# 1           627   00:01.9  10:29.8             274.0
# 2          1132   00:04.0  18:56.2            2000.0
# 3          1780   00:04.2  29:44.8             479.0
# 4          1517   00:05.5  25:23.5            3312.0
#
#                start station name  start station latitude  \
# 0          Forsyth St & Broome St               40.718939
# 1  Lafayette Ave & Fort Greene Pl               40.686919
# 2        Front St & Washington St               40.702551
# 3                 9 Ave & W 45 St               40.760193
# 4                 1 Ave & E 94 St               40.781721
#
#    start station longitude  end station id            end station name  \
# 0               -73.992663           408.0       Market St & Cherry St
# 1               -73.976682          3409.0        Bergen St & Smith St
# 2               -73.989402          3388.0     President St & Henry St
# ...

# %%
df16 = pd.read_csv("Sept2019Clean.csv")
df16.head()
# Out:
#    tripduration starttime stoptime  start station id  \
# 0           327   00:02.0  05:29.3              3733
# 1          1145   00:04.1  19:09.8              3329
# 2          1293   00:07.3  21:40.8              3168
# 3          1753   00:08.1  29:21.5              3299
# 4           613   00:12.9  10:26.2               486
#
#             start station name  start station latitude  \
# 0           Avenue C & E 18 St               40.730563
# 1         Degraw St & Smith St               40.682915
# 2  Central Park West & W 85 St               40.784727
# 3           E 98 St & Park Ave               40.788130
# 4           Broadway & W 29 St               40.746201
#
#    start station longitude  end station id             end station name  \
# 0               -73.973984             504              1 Ave & E 16 St
# 1               -73.993182             270      Adelphi St & Myrtle Ave
# 2               -73.969617             423              W 54 St & 9 Ave
# ...

# %%
cmp2019_df = pd.concat([df11,df12,df13,df14,df15,df16], ignore_index=True)

# %%
cmp2019_df.to_csv('2019Clean.csv')
